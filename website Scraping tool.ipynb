# %%
# website data extraction tool using python.

# The project automates the procss of collecting data from website.

# It quickly extract large amounts of data which saves time and effort compared to manual extraction. 

# It provide real-time information, allows us to stay updated with web changes.

# We can use the Extracted  data for different purposes like Data Analysis, Marketing and promotion.

# It can be used for Creating reports and analysis, also for Research and academic purposes.

# %%
# COMPLETE PROJECT

# %%
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

# To Create a connection with browse

browser = webdriver.Chrome()

# To Maximize the browser window
browser.maximize_window()

# For Opening the website
browser.get("https://www.knowafest.com/explore/upcomingfests")

# Accessed Table from website by ID  

table=browser.find_element(By.ID,"tablaDatos")

# searching the elements within the table
# TO Access Table Body (tbody tag)

tbody = table.find_element(By.TAG_NAME,"tbody")

# Accessed ALL table rows (tr tags) within table body (tbody tag) 

tr_list= tbody.find_elements(By.TAG_NAME,"tr")

# For Making DataFrame used pandas library

import pandas as pd

# Created Empty Lists for appending All Table Data Elements from All Table Rows except FIRST TABLE ROW

Event_Name_list = []
Event_Start_Date_list = []
Event_Type_list = []
Event_Organiser_Name_list = []
Event_Address_list = []
Event_End_Date_list = []
Event_Organiser_Email_list = []

i=0
for tr in tr_list:
    if i==0:
        i+=1
        continue
        
   
    td_list = tr.find_elements(By.TAG_NAME, "td") # Extracted Each table row -> ALL table data elements ; EXCEPT FIRST TABLE ROW 
    
    start_date = td_list[0].text
    event_name = td_list[1].text # Another way of fetching the element    
    
    read_more_button = td_list[1].find_element(By.XPATH,".//span[@class='btn btn-sm u-btn-skew u-btn-primary g-mr-10 g-mb-15']")
    browser.execute_script("arguments[0].scrollIntoView();", read_more_button)
    read_more_button.click()

    # Switched to the newly opened tab
    
    current_window = browser.current_window_handle
    browser.switch_to.window(browser.window_handles[1])
    time.sleep(5)
    
    
    
    try:
        divclass = browser.find_element(By.XPATH, "//div[@class='card-body']")
        a_tags = divclass.find_elements(By.XPATH, "//a[@class='link link-secondary link-pointer']")
             
    # Above, It finds the email address of the event organizer by searching for an HTML element with the class "card-body" 
    
    
    # If a matching email address is found, it assigns it to the variable "event_organiser_email". If no match is found, it assigns the value "N/A" to the variable.
    
        for a_tag in a_tags:
            if a_tag.get_attribute("href").startswith("mailto:"):
                event_organiser_email = a_tag.get_attribute("href").split(":")[1]
                break
    except NoSuchElementException:
        event_organiser_email = "N/A"
  
   
    # Switched back to the original window
    browser.close()
    browser.switch_to.window(current_window)
    time.sleep(5)

    event_type = td_list[2].text
    event_location_data = td_list[3]
    event_end_date = td_list[4].text

    span_tag_list_elements_within_td_tag_elements = event_location_data.find_elements(By.TAG_NAME,"span")
    event_organiser_name = span_tag_list_elements_within_td_tag_elements[1].text
    event_address = span_tag_list_elements_within_td_tag_elements[2].text
          
    print("Event_Name:",    event_name, 
          "Event_Start_Date:",   start_date, 
          "Event_Type:",  event_type,
          "Event_Organiser_Name:",  event_organiser_name , 
          "Event_Address: ",   event_address, 
          "Event_End_Date:",   event_end_date,
          "Event_Organiser_Email:",event_organiser_email)
    print("\n\n")
    
    Event_Name_list.append(event_name)
    Event_Start_Date_list.append(start_date)
    Event_Type_list.append(event_type)
    Event_Organiser_Name_list.append( event_organiser_name)
    Event_Address_list.append(event_address)
    Event_End_Date_list.append(event_end_date)
    Event_Organiser_Email_list.append(event_organiser_email)

result_dict = {"Event Name": Event_Name_list, "Event Start Date": Event_Start_Date_list, "Event Type": Event_Type_list,
               "Event Oraganiser Name": Event_Organiser_Name_list, "Event Address":Event_Address_list, 
               "Event End Date": Event_End_Date_list, "Event Organiser Email": Event_Organiser_Email_list}

my_data2 = pd.DataFrame(data=result_dict)
# Out:
# The version of chrome cannot be detected. Trying with latest driver version
# Event_Name: One Day Workshop on IoT and its application in Industry 2023 Read More Event_Start_Date: 15 Jul 2023 Event_Type: Workshop Event_Organiser_Name: SNS College of Technology, Event_Address:  Coimbatore, Tamil Nadu Event_End_Date: 15 Jul 2023 Event_Organiser_Email: aamirkhan.a.aero.2022@snsct.org
#
#
#
# Event_Name: Embedded System Design Workshop 2023 Read More Event_Start_Date: 15 Jul 2023 Event_Type: Workshop Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 15 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: IoT using Python and Raspberry Pi Workshop 2023 Read More Event_Start_Date: 15 Jul 2023 Event_Type: Workshop Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 15 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: IoT Workshop 2023 Read More Event_Start_Date: 16 Jul 2023 Event_Type: Workshop Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 16 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: International IC Engines and EV Workshop 2023 Read More Event_Start_Date: 16 Jul 2023 Event_Type: Workshop Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 16 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: International Four Days offline Faculty Development Program on Hybrid and Electric Vehicles 2023 Read More Event_Start_Date: 17 Jul 2023 Event_Type: Faculty Development Program Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 20 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: One Week International Skill Development Course on Product Design (online Mode) 2023 Read More Event_Start_Date: 17 Jul 2023 Event_Type: Skill Development Program Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 23 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: 10 Days International Industrial Training on Deep Learning for Computer Vision using Python (online Mode) 2023 Read More Event_Start_Date: 17 Jul 2023 Event_Type: Training Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 26 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: 5 Days International Career Development Course on Social Media Marketing - Buisness Impact (online Mode) 2023 Read More Event_Start_Date: 17 Jul 2023 Event_Type: Career Development Course Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 21 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: Equipping Educators: Faculty Development Program on Emerging Technologies in Mechanical Engineering 2023 Read More Event_Start_Date: 17 Jul 2023 Event_Type: Faculty Development Program Event_Organiser_Name: Ramco Institute of Technology, Event_Address:  Rajapalayam, Tamil Nadu Event_End_Date: 21 Jul 2023 Event_Organiser_Email: mech@ritrjpm.ac.in
#
#
#
# Event_Name: National Level FDP on Recent Advancements in Electric Vehicle Technologies 2023 Read More Event_Start_Date: 17 Jul 2023 Event_Type: Faculty Development Program Event_Organiser_Name: M Kumarasamy College of Engineering (Autonomous), Event_Address:  Karur, Tamil Nadu Event_End_Date: 21 Jul 2023 Event_Organiser_Email: banumathis.eee@mkce.ac.in
#
#
#
# Event_Name: 5 days Online Short Term Training Program on Machine Learning and Deep Learning with Data Science 2023 Read More Event_Start_Date: 17 Jul 2023 Event_Type: Short Term Training Program Event_Organiser_Name: CARE College of Engineering, Event_Address:  Tiruchirappalli, Tamil Nadu Event_End_Date: 21 Jul 2023 Event_Organiser_Email: vgomathi@care.ac.in
#
#
#
# Event_Name: 10 Days International Skill Development Training on Advanced Level Strategic Plan Writing (online Mode) 2023 Read More Event_Start_Date: 18 Jul 2023 Event_Type: Skill Development Training Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 27 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: 5 Days International Workshop on Advanced Automotive Technologies (Hybrid Mode) 2023 Read More Event_Start_Date: 19 Jul 2023 Event_Type: International Workshop Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 23 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: National Digital Security Summit 2023 Read More Event_Start_Date: 21 Jul 2023 Event_Type: Summit Event_Organiser_Name: Kalaignar Karunanidhi Institute of Technology, Event_Address:  Coimbatore, Tamil Nadu Event_End_Date: 22 Jul 2023 Event_Organiser_Email: kithodad@gmail.com
#
#
#
# Event_Name: PCB Design Workshop 2023 Read More Event_Start_Date: 22 Jul 2023 Event_Type: Workshop Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 22 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: International Latest Trends in Automotive Technologies 2023 Read More Event_Start_Date: 22 Jul 2023 Event_Type: Workshop Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 22 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: One Day Hands on Training Cum Workshop on Food Waste Utilization for Biogas Production 2023 Read More Event_Start_Date: 22 Jul 2023 Event_Type: Hands on Training Event_Organiser_Name: Sathyabama Institute of Science and Technology, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 22 Jul 2023 Event_Organiser_Email: centreworkcwm@gmail.com
#
#
#
# Event_Name: One day Training on Bench Scale Biodiesel Production and Characterization as per ASTM Standards 2023 Read More Event_Start_Date: 22 Jul 2023 Event_Type: Training Event_Organiser_Name: Sathyabama Institute of Science and Technology, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 22 Jul 2023 Event_Organiser_Email: centreworkcwm@gmail.com
#
#
#
# Event_Name: EGraphie5.0 Read More Event_Start_Date: 22 Jul 2023 Event_Type: National Level Technical Contest Event_Organiser_Name: Jansons Institute of Technology, Event_Address:  Coimbatore, Tamil Nadu Event_End_Date: 22 Jul 2023 Event_Organiser_Email: egraphie19@gmail.com
#
#
#
# Event_Name: Microcontroller Workshop 2023 Read More Event_Start_Date: 23 Jul 2023 Event_Type: Workshop Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 23 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: International IC Engines, EV and Hybrid Workshop 2023 Read More Event_Start_Date: 23 Jul 2023 Event_Type: Workshop Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 23 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: Workshop on Big Data Analytics in the year 2023 Read More Event_Start_Date: 24 Jul 2023 Event_Type: Workshop Event_Organiser_Name: CARE College of Engineering, Event_Address:  Tiruchirappalli, Tamil Nadu Event_End_Date: 26 Jul 2023 Event_Organiser_Email: fshakilabanu@care.ac.in
#
#
#
# Event_Name: 7 Days International Crash Course on Ic Engine Technology using Virtual Reality (hybrid Mode) 2023 Read More Event_Start_Date: 24 Jul 2023 Event_Type: Short Term Course Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 30 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: Embedded Systems and IoT with Hands-on Session arduino and Raspberry Pi 2023 Read More Event_Start_Date: 24 Jul 2023 Event_Type: Faculty Development Program Event_Organiser_Name: Saranathan College of Engineering, Event_Address:  Tiruchirappalli, Tamil Nadu Event_End_Date: 28 Jul 2023 Event_Organiser_Email: saraece2023@gmail.com
#
#
#
# Event_Name: Virtual Third International Conference in Modern Computing trends and Technology ICMCTT 2023 Read More Event_Start_Date: 26 Jul 2023 Event_Type: Virtual International Conference Event_Organiser_Name: Kristu Jyoti College of Management and Technology & RSP Conference Hub, Event_Address:  Changanacherry, Kerala Event_End_Date: 27 Jul 2023 Event_Organiser_Email: editorrspconferencehub@gmail.com
#
#
#
# Event_Name: 2 Days International Virtual Workshop on Multimedia 2023 Read More Event_Start_Date: 27 Jul 2023 Event_Type: International Virtual Workshop Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 28 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: National Level Workshop on Machine Learning Techniques for EEG Signal Processing 2023 Read More Event_Start_Date: 27 Jul 2023 Event_Type: Workshop Event_Organiser_Name: Karpagam College of Engineering, Event_Address:  Coimbatore, Tamil Nadu Event_End_Date: 27 Jul 2023 Event_Organiser_Email: dharanika.t@kce.ac.in
#
#
#
# Event_Name: Data Analytics with Python 2023 Read More Event_Start_Date: 28 Jul 2023 Event_Type: Workshop Event_Organiser_Name: Karpagam College of Engineering, Event_Address:  Coimbatore, Tamil Nadu Event_End_Date: 28 Jul 2023 Event_Organiser_Email: malini.s@kce.ac.in
#
#
#
# Event_Name: Faculty Development Program on Applications of Power Electronics in Automotive Industries 2023 Read More Event_Start_Date: 28 Jul 2023 Event_Type: Faculty Development Program Event_Organiser_Name: Vellore Institute of Technology, Event_Address:  Vellore, Tamil Nadu Event_End_Date: 30 Jul 2023 Event_Organiser_Email: satyajit.das@vit.ac.in
#
#
#
# Event_Name: IoT Workshop 2023 Read More Event_Start_Date: 29 Jul 2023 Event_Type: Workshop Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 29 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: IoT using Python and Raspberry Pi Workshop 2023 Read More Event_Start_Date: 29 Jul 2023 Event_Type: Workshop Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 29 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: 2 Days International Virtual Workshop on Cyber Security 2023 Read More Event_Start_Date: 29 Jul 2023 Event_Type: International Virtual Workshop Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 30 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: Embedded System Design Workshop 2023 Read More Event_Start_Date: 30 Jul 2023 Event_Type: Workshop Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 30 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: WEB (Website) Development Workshop 2023 Read More Event_Start_Date: 30 Jul 2023 Event_Type: Workshop Event_Organiser_Name: Top Engineers, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 30 Jul 2023 Event_Organiser_Email: topengineers2015@gmail.com
#
#
#
# Event_Name: One day Training on Proximate Analysis and Characterization of Biomass for Bio ethanol Production 2023 Read More Event_Start_Date: 31 Jul 2023 Event_Type: Hands on Training Event_Organiser_Name: Sathyabama Institute of Science and Technology, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 31 Jul 2023 Event_Organiser_Email: pdharsini49@gmail.com
#
#
#
# Event_Name: National Concrete Canoe Competition Phoenix 2K23 Read More Event_Start_Date: 02 Aug 2023 Event_Type: Canoe Competition Event_Organiser_Name: Shri Vishnu Engineering College for Women, Event_Address:  Bhimavaram, Andhra Pradesh Event_End_Date: 04 Aug 2023 Event_Organiser_Email: ceevents@svecw.edu.in
#
#
#
# Event_Name: 5th International Conference on Inventive Research in Computing Applications ICIRCA-2023 Read More Event_Start_Date: 03 Aug 2023 Event_Type: International Conference Event_Organiser_Name: RVS College of Engineering and Technology Coimbatore, Event_Address:  Coimbatore, Tamil Nadu Event_End_Date: 05 Aug 2023 Event_Organiser_Email: icirca.conf@gmail.com
#
#
#
# Event_Name: International Conference on Global Business Management, Entrepreneurship and Social Research 2023 Read More Event_Start_Date: 03 Aug 2023 Event_Type: International Conference Event_Organiser_Name: KV Institute of Management and Information Studies, Event_Address:  Coimbatore, Tamil Nadu Event_End_Date: 04 Aug 2023 Event_Organiser_Email: research@kvimis.co.in
#
#
#
# Event_Name: One day Training on Pilot Scale Biodiesel Production and Characterization as per ASTM Standards 2023 Read More Event_Start_Date: 05 Aug 2023 Event_Type: Training Event_Organiser_Name: Sathyabama Institute of Science and Technology, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 05 Aug 2023 Event_Organiser_Email: centreworkcwm@gmail.com
#
#
#
# Event_Name: CRYPTRIX'23 Read More Event_Start_Date: 05 Aug 2023 Event_Type: Technical Symposium Event_Organiser_Name: St. Joseph's College of Engineering, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 05 Aug 2023 Event_Organiser_Email: kernel23symposium@gmail.com
#
#
#
# Event_Name: 8th World Nursing congress 2023 Read More Event_Start_Date: 07 Aug 2023 Event_Type: Conference Event_Organiser_Name: Inovine Meetings LLC, Event_Address:  London, NA Event_End_Date: 08 Aug 2023 Event_Organiser_Email: N/A
#
#
#
# Event_Name: 7th International Conference on Advanced Dental Education and Research 2023 Read More Event_Start_Date: 07 Aug 2023 Event_Type: International Conference Event_Organiser_Name: Alfa College of Engineering and Technology, Event_Address:  Kurnool, Andhra Pradesh Event_End_Date: 08 Aug 2023 Event_Organiser_Email: jessicamartin3349@gmail.com
#
#
#
# Event_Name: 4th International Conferenece on Robotics, automation and Non-destructive Evaluation RANE 2023 Read More Event_Start_Date: 07 Aug 2023 Event_Type: International Conference Event_Organiser_Name: Hindustan Institute of Technology and Science, Event_Address:  Chennai, Tamil Nadu Event_End_Date: 07 Aug 2023 Event_Organiser_Email: hitsrane23@gmail.com
#
#
#
# Event_Name: International Biotechnology Conclave 'BioZion-The Biotech Capstone' 2023 Read More Event_Start_Date: 07 Aug 2023 Event_Type: Conclave Event_Organiser_Name: College of Agriculture Vellayani, Event_Address:  Thiruvananthapuram, Kerala Event_End_Date: 11 Aug 2023 Event_Organiser_Email: biozion2023@gmail.com
#
#
#
# Event_Name: BioZion 2023 Read More Event_Start_Date: 07 Aug 2023 Event_Type: Techno Cultural Fest Event_Organiser_Name: College of Agriculture Vellayani, Event_Address:  Thiruvananthapuram, Kerala Event_End_Date: 12 Aug 2023 Event_Organiser_Email: biozion2023@gmail.com
#
#
#
# Event_Name: 4th International Conference on Image Processing and Capsule Networks ICIPCN 2023 Read More Event_Start_Date: 10 Aug 2023 Event_Type: International Conference Event_Organiser_Name: Tribhuvan University (Pulchowk Campus), Event_Address:  Bangkok, NA Event_End_Date: 11 Aug 2023 Event_Organiser_Email: icipcn.conf@gmail.com
#
#
#
# Event_Name: 4th International Conference on Image Processing and Capsule Networks ICIPCN - 2023 Read More Event_Start_Date: 10 Aug 2023 Event_Type: International Conference Event_Organiser_Name: Tribhuvan University, Event_Address:  Bangkok, NA Event_End_Date: 11 Aug 2023 Event_Organiser_Email: icipcn.conf@gmail.com
#
#
#
# Event_Name: TECH NIMBLE 2023 Read More Event_Start_Date: 10 Aug 2023 Event_Type: Techno Fun Festival Event_Organiser_Name: Nadimpalli Satyanarayana Raju Institute of Technology, Event_Address:  Visakhapatnam, Andhra Pradesh Event_End_Date: 12 Aug 2023 Event_Organiser_Email: technimble2k23@nsrit.edu.in
#
#
#
# Event_Name: National Electric Tractor Design Championship (NETDC-23) Read More Event_Start_Date: 18 Aug 2023 Event_Type: Design Championship Event_Organiser_Name: Bannari Amman Institute of Technology, Event_Address:  Erode, Tamil Nadu Event_End_Date: 19 Aug 2023 Event_Organiser_Email: deepankumar@bitsathy.ac.in
#
#
#
# Event_Name: National Electric Tractor Design Championship (NETDC-23) Read More Event_Start_Date: 18 Aug 2023 Event_Type: Technical Event Event_Organiser_Name: Bannari Amman Institute of Technology, Event_Address:  Erode, Tamil Nadu Event_End_Date: 19 Aug 2023 Event_Organiser_Email: deepankumar@bitsathy.ac.in
#
#
#
# Event_Name: International Nursing Science Conference 2023 Read More Event_Start_Date: 21 Aug 2023 Event_Type: International Conference Event_Organiser_Name: Magnus Group LLC, Event_Address:  London UK, NA Event_End_Date: 23 Aug 2023 Event_Organiser_Email: N/A
#
#
#
# Event_Name: Five Days Short Term Training Program (STTP) on Breaking Boundaries in Healthcare: Futuristic Antenna Technology and AI for Telemedicine and Biomedical Applications 2023 Read More Event_Start_Date: 21 Aug 2023 Event_Type: Training Program Event_Organiser_Name: CARE College of Engineering, Event_Address:  Tiruchirappalli, Tamil Nadu Event_End_Date: 25 Aug 2023 Event_Organiser_Email: rdeepalakshmi@care.ac.in
#
#
#
# Event_Name: International Conference in Management and IT: the Era of 17 SDGs 2023 Read More Event_Start_Date: 24 Aug 2023 Event_Type: International Conference Event_Organiser_Name: Ideal Institute of Management and Technology and School of Law, Event_Address:  Delhi, Delhi Event_End_Date: 24 Aug 2023 Event_Organiser_Email: conference.iimt23@gmail.com
#
#
#
# Event_Name: 5th Edition of Euro Global Conference on Pediatrics and Neonatology EPN 2023 Read More Event_Start_Date: 28 Aug 2023 Event_Type: International Conference Event_Organiser_Name: Magnus Group LLC, Event_Address:  London, NA Event_End_Date: 30 Aug 2023 Event_Organiser_Email: N/A
#
#
#
# Event_Name: 5th Edition of Euro Global Conference on Pediatrics and Neonatology 2023 Read More Event_Start_Date: 28 Aug 2023 Event_Type: International Conference Event_Organiser_Name: Magnus Group LLC, Event_Address:  Slough, NA Event_End_Date: 30 Aug 2023 Event_Organiser_Email: N/A
#
#
#
# Event_Name: 2nd International Conference on Smart Sustainable Materials and Technologies ICSSMT 2023 Read More Event_Start_Date: 30 Aug 2023 Event_Type: International Conference Event_Organiser_Name: CARE Group of Institutions, Event_Address:  Tiruchirappalli, Tamil Nadu Event_End_Date: 31 Aug 2023 Event_Organiser_Email: icssmt.conf@gmail.com
#
#
#
# Event_Name: ICSD 2023 : 11th International Conference on Sustainable Development 2023 Read More Event_Start_Date: 06 Sep 2023 Event_Type: International Conference Event_Organiser_Name: European Center of Sustainable Development - CIT University, Event_Address:  Rome, NA Event_End_Date: 07 Sep 2023 Event_Organiser_Email: conference@ecsdev.org
#
#
#
# Event_Name: International Nursing and Healthcare Conference 2023 Read More Event_Start_Date: 11 Sep 2023 Event_Type: International Conference Event_Organiser_Name: Mastersmind Scientific Meetings, Event_Address:  Paris, NA Event_End_Date: 12 Sep 2023 Event_Organiser_Email: mastersmindconferences@gmail.com
#
#
#
# Event_Name: International Conference on Evolutionary Artificial Intelligence ICEAI 2023 Read More Event_Start_Date: 13 Sep 2023 Event_Type: International Conference Event_Organiser_Name: Taylor’s University, Event_Address:  Subang Jaya, NA Event_End_Date: 14 Sep 2023 Event_Organiser_Email: iceai.contact@gmail.com
#
#
#
# Event_Name: SCHEMCON'23 Read More Event_Start_Date: 22 Sep 2023 Event_Type: Conference Event_Organiser_Name: Kongu Engineering College, Event_Address:  Erode, Tamil Nadu Event_End_Date: 23 Sep 2023 Event_Organiser_Email: schemcon2023@kongu.edu
#
#
#
# Event_Name: 29th World Congress on Dentistry and Oral Health 2023 Read More Event_Start_Date: 25 Sep 2023 Event_Type: International Conference Event_Organiser_Name: Conference Series LLC Ltd, Event_Address:  Zurich, NA Event_End_Date: 26 Sep 2023 Event_Organiser_Email: dentistrycongress@europemeets.com
#
#
#
# Event_Name: World Congress on Advances in Mental Health and Psychiatry 2023 Read More Event_Start_Date: 25 Sep 2023 Event_Type: Conference Event_Organiser_Name: Scholars Conferences, Event_Address:  Paris, NA Event_End_Date: 26 Sep 2023 Event_Organiser_Email: mentalhealth@scholarconferences.org
#
#
#
# Event_Name: International Conference on Information and Communication Engineering (ICICE '23) Read More Event_Start_Date: 27 Sep 2023 Event_Type: International Conference Event_Organiser_Name: CARE College of Engineering, Event_Address:  Tiruchirappalli, Tamil Nadu Event_End_Date: 28 Sep 2023 Event_Organiser_Email: rdeepalakshmi@care.ac.in
#
#
#
# Event_Name: 9th International Conference on Nursing Education and Health Care 2023 Read More Event_Start_Date: 16 Oct 2023 Event_Type: International Conference Event_Organiser_Name: Inovine Meetings LLC, Event_Address:  San Francisco, NA Event_End_Date: 17 Oct 2023 Event_Organiser_Email: N/A
#
#
#
# Event_Name: International conference on Pharmaceutical and Pharma Industry Pharmaceutics 2023 Read More Event_Start_Date: 16 Oct 2023 Event_Type: International Conference Event_Organiser_Name: Pulsus Group , Event_Address:  Paris, NA Event_End_Date: 18 Oct 2023 Event_Organiser_Email: pharmaceutics@pulsusforums.com
#
#
#
# Event_Name: World Nursing and Healthcare Summit WNHS 2023 Read More Event_Start_Date: 23 Oct 2023 Event_Type: Conference Event_Organiser_Name: Scholars Conferences, Event_Address:  Chiba, NA Event_End_Date: 24 Oct 2023 Event_Organiser_Email: N/A
#
#
#
# Event_Name: 3rd International Conference on Nursing and Women’s Healthcare 2023 Read More Event_Start_Date: 13 Nov 2023 Event_Type: International Conference Event_Organiser_Name: Scientex Conferences, Event_Address:  Dubai, NA Event_End_Date: 14 Nov 2023 Event_Organiser_Email: N/A
#
#
#
# Event_Name: 3rd International Conference on Nutrition and Healthcare 2023 Read More Event_Start_Date: 16 Nov 2023 Event_Type: International Conference Event_Organiser_Name: Scientex Conferences, Event_Address:  Dubai, NA Event_End_Date: 17 Nov 2023 Event_Organiser_Email: N/A
#
#
#
# Event_Name: 3rd International Conference on Neuroscience and Psychiatry 2023 Read More Event_Start_Date: 16 Nov 2023 Event_Type: International Conference Event_Organiser_Name: Scientex, Event_Address:  Dubai, NA Event_End_Date: 17 Nov 2023 Event_Organiser_Email: N/A
#
#
#
# Event_Name: 7th International Conference on Electronics, Communication and Aerospace Technology ICECA 2023 Read More Event_Start_Date: 22 Nov 2023 Event_Type: International Conference Event_Organiser_Name: RVS Technical Campus, Event_Address:  Coimbatore, Tamil Nadu Event_End_Date: 24 Nov 2023 Event_Organiser_Email: iceacconfteam@gmail.com
#
#
#
# Event_Name: 3rd International Conference on Otorhinolaryngology 2023 Read More Event_Start_Date: 27 Nov 2023 Event_Type: International Conference Event_Organiser_Name: Scientex Conferences, Event_Address:  Dubai, NA Event_End_Date: 28 Nov 2023 Event_Organiser_Email: N/A
#
#
#
# Event_Name: 3rd International Conference on Cardiology (Hybrid Event) Heart 2023 Read More Event_Start_Date: 30 Nov 2023 Event_Type: International Conference Event_Organiser_Name: Scientex Conferences, Event_Address:  Dubai, NA Event_End_Date: 01 Dec 2023 Event_Organiser_Email: N/A
#
#
#
# Event_Name: 3rd International Conference on Oncology Research and Treatment Oncology 2023 Read More Event_Start_Date: 30 Nov 2023 Event_Type: International Conference Event_Organiser_Name: Scientex Conferences, Event_Address:  Dubai, NA Event_End_Date: 01 Dec 2023 Event_Organiser_Email: N/A
#
#
#
# Event_Name: World Conference on Breast Cancer and Therapeutics 2023 Read More Event_Start_Date: 30 Nov 2023 Event_Type: International Conference Event_Organiser_Name: Scientex Conferences, Event_Address:  Dubai, NA Event_End_Date: 01 Dec 2023 Event_Organiser_Email: N/A
#
#
#
# Event_Name: 2nd International Conference on Automation, Computing and Renewable Systems ICACRS 2023 Read More Event_Start_Date: 11 Dec 2023 Event_Type: International Conference Event_Organiser_Name: Mount Zion College of Engineering and Technology, Event_Address:  Pudukkottai, Tamil Nadu Event_End_Date: 13 Dec 2023 Event_Organiser_Email: icacrs.confe@gmail.com
#
#
#
# Event_Name: 3rd International Conference on Surgery and Anesthesia 2023 Read More Event_Start_Date: 23 Dec 2023 Event_Type: International Conference Event_Organiser_Name: Scientex Conference, Event_Address:  Dubai, NA Event_End_Date: 24 Dec 2023 Event_Organiser_Email: N/A
#
#
#
# Event_Name: ICCNCT 2023 Read More Event_Start_Date: 27 Feb 2024 Event_Type: International Conference Event_Organiser_Name: RVS Technical Campus, Event_Address:  Coimbatore, Tamil Nadu Event_End_Date: 28 Feb 2024 Event_Organiser_Email: iccnct.contact@gmail.com
#
#
#
# Event_Name: 2nd International Conference on Dermatology and Cosmetology 2023 Read More Event_Start_Date: 09 May 2024 Event_Type: International Conference Event_Organiser_Name: Scientex Conference, Event_Address:  Bangkok, NA Event_End_Date: 10 May 2024 Event_Organiser_Email: dermatology@scientexconferences.com
#
#
#
# Event_Name: 2nd International Conference on Pediatrics and Healthcare Pediatrics 2024 Read More Event_Start_Date: 13 May 2024 Event_Type: International Conference Event_Organiser_Name: Scientex Conferences, Event_Address:  Bangkok, NA Event_End_Date: 14 May 2024 Event_Organiser_Email: pediatric.scientex@gmail.com
#
#
#
# Event_Name: 2nd International Conference on Gynecology and Obstetrics Gynaecology 2024 Read More Event_Start_Date: 13 May 2024 Event_Type: International Conference Event_Organiser_Name: Scientex Conferences, Event_Address:  Bangkok, NA Event_End_Date: 14 May 2024 Event_Organiser_Email: gynaecology@scientexconferences.com
#
#
#
# Event_Name: 2nd International Conference on Global Healthcare 2023 Read More Event_Start_Date: 13 May 2024 Event_Type: International Conference Event_Organiser_Name: Wyoming, Event_Address:  Wyoming, NA Event_End_Date: 14 May 2024 Event_Organiser_Email: N/A

# %%
my_data2
# Out:
#                                            Event Name Event Start Date  \
# 0   One Day Workshop on IoT and its application in...      15 Jul 2023
# 1      Embedded System Design Workshop 2023 Read More      15 Jul 2023
# 2   IoT using Python and Raspberry Pi Workshop 202...      15 Jul 2023
# 3                         IoT Workshop 2023 Read More      16 Jul 2023
# 4   International IC Engines and EV Workshop 2023 ...      16 Jul 2023
# ..                                                ...              ...
# 77                              ICCNCT 2023 Read More      27 Feb 2024
# 78  2nd International Conference on Dermatology an...      09 May 2024
# 79  2nd International Conference on Pediatrics and...      13 May 2024
# 80  2nd International Conference on Gynecology and...      13 May 2024
# 81  2nd International Conference on Global Healthc...      13 May 2024
#
#                   Event Type       Event Oraganiser Name  \
# 0                   Workshop  SNS College of Technology,
# 1                   Workshop              Top Engineers,
# 2                   Workshop              Top Engineers,
# 3                   Workshop              Top Engineers,
# 4                   Workshop              Top Engineers,
# ..                       ...                         ...
# 77  International Conference       RVS Technical Campus,
# 78  International Conference        Scientex Conference,
# 79  International Conference       Scientex Conferences,
# 80  International Conference       Scientex Conferences,
# 81  International Conference                    Wyoming,
#
#              Event Address Event End Date                Event Organiser Email
# 0   Coimbatore, Tamil Nadu    15 Jul 2023      aamirkhan.a.aero.2022@snsct.org
# 1      Chennai, Tamil Nadu    15 Jul 2023           topengineers2015@gmail.com
# 2      Chennai, Tamil Nadu    15 Jul 2023           topengineers2015@gmail.com
# 3      Chennai, Tamil Nadu    16 Jul 2023           topengineers2015@gmail.com
# 4      Chennai, Tamil Nadu    16 Jul 2023           topengineers2015@gmail.com
# ..                     ...            ...                                  ...
# 77  Coimbatore, Tamil Nadu    28 Feb 2024             iccnct.contact@gmail.com
# 78             Bangkok, NA    10 May 2024  dermatology@scientexconferences.com
# 79             Bangkok, NA    14 May 2024         pediatric.scientex@gmail.com
# 80             Bangkok, NA    14 May 2024  gynaecology@scientexconferences.com
# 81             Wyoming, NA    14 May 2024                                  N/A
#
# [82 rows x 7 columns]

# %%
# Export the data to a csv file
my_data2.to_csv("KNOW A FEST EVENTS LISTS WITH EVENT ORGANIZERS EMAIL.csv")
